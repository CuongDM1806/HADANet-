# %% [markdown]
# # HADANet PhysioNet S001-S020 strict LOSO
# Enable a GPU runtime before running this single code cell.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !if [ -d /content/HADANet-/.git ]; then git -C /content/HADANet- fetch origin feature/strict-physionet-loso && git -C /content/HADANet- checkout feature/strict-physionet-loso && git -C /content/HADANet- pull --ff-only origin feature/strict-physionet-loso; else git clone --branch feature/strict-physionet-loso --single-branch https://github.com/CuongDM1806/HADANet-.git /content/HADANet-; fi
# !python -m pip install -q -r /content/HADANet-/requirements_loso.txt
# !PYTHONUNBUFFERED=1 python -u /content/HADANet-/train_physionet_loso.py --subjects 1-20 --targets 1-20 --epochs 150 --batch-size 40 --validation-fraction 0.05 --device auto --data-dir /content/drive/MyDrive/datasets/PhysioNetEEGMMIDB --cache-dir /content/drive/MyDrive/datasets/PhysioNetEEGMMIDB_DE --results-dir /content/drive/MyDrive/HADANet-results/physionet-loso
