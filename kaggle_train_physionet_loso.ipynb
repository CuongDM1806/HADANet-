# %% [markdown]
# # HADANet PhysioNet S001-S020 strict LOSO
# Enable GPU and Internet in Kaggle before running this single code cell.

# %%
# %cd /kaggle/working
# !if [ -d HADANet-/.git ]; then git -C HADANet- fetch origin feature/strict-physionet-loso && git -C HADANet- checkout feature/strict-physionet-loso && git -C HADANet- pull --ff-only origin feature/strict-physionet-loso; else git clone --branch feature/strict-physionet-loso --single-branch https://github.com/CuongDM1806/HADANet-.git HADANet-; fi
# !python -m pip install -q -r /kaggle/working/HADANet-/requirements_loso.txt
# !PYTHONUNBUFFERED=1 python -u /kaggle/working/HADANet-/train_physionet_loso.py --subjects 1-20 --targets 1-20 --epochs 150 --batch-size 15 --validation-fraction 0.05 --device auto --data-dir /kaggle/working/physionet_raw --cache-dir /kaggle/working/physionet_de --results-dir /kaggle/working/hadanet_results
# !cd /kaggle/working && zip -qr hadanet_physionet_loso_results.zip hadanet_results
